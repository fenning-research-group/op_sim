# %%
# %config InlineBackend.figure_format = 'retina'
import os
from FDTD import FDTD_processing
import frgtools.misc as frgm
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import style
mpl.rcParams.update(mpl.rcParamsDefault)
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Checking single experiment

# %%
#change these
FDTD_rootdir = os.path.join('FDTD_Simulation_Outputs', '20200713', '1.5eV', '350nm')
Spectrum_fp = os.path.join('Spectrum_Import','AM15.csv')
RayTracing_fp = os.path.join('RT_Outputs','RAT_data_7.csv')

#keep these
R_fp = os.path.join(FDTD_rootdir,'reflection_export.txt')
T_fp = os.path.join(FDTD_rootdir,'transmission_export.txt')
PSK_fp = os.path.join(FDTD_rootdir,'PSK_EQE.txt')
SI_fp = os.path.join(FDTD_rootdir,'Si_EQE.txt')

FDTD_processing.FDTD_load(R_fp, T_fp, PSK_fp, SI_fp, Spectrum_fp, RayTracing_fp, Gap_cutoff=117, monitor_rez=200, plot=False)
# Out:
# {'R_Jsc': 1.3510212175916465,
#  'PA_Jsc': 2.3160305865285604,
#  'PSK_Jsc': 19.60279434205424,
#  'Si_Jsc': 19.983577902024564}

# %% [markdown]
# ### Batch Gathering Multiple Experimens

# %%
fids = frgm.listdir()
fidsearch=frgm.searchdir('.', ['20200719', '20200713'], ignore=['Picture','ITO','FullConformalPyramid','trans','ref','PSK','HTL', 'ETL', 'lambdaT'], match_directories=True)

# %%
for n in range(len(fidsearch)):
    fidsearch[n] = os.path.split(fidsearch[n])[0]
fidsearch
# Out:
# ['/Volumes/GoogleDrive/My Drive/Optical_Simulations/FDTD_Simulation_Outputs/20200713/1.5eV/650nm',
#  '/Volumes/GoogleDrive/My Drive/Optical_Simulations/FDTD_Simulation_Outputs/20200713/1.5eV/350nm',
#  '/Volumes/GoogleDrive/My Drive/Optical_Simulations/FDTD_Simulation_Outputs/20200713/1.5eV/500nm',
#  '/Volumes/GoogleDrive/My Drive/Optical_Simulations/FDTD_Simulation_Outputs/20200719/1.75eV/350nm',
#  '/Volumes/GoogleDrive/My Drive/Optical_Simulations/FDTD_Simulation_Outputs/20200719/1.75eV/500nm',
#  '/Volumes/GoogleDrive/My Drive/Optical_Simulations/FDTD_Simulation_Outputs/20200719/1.75eV/650nm',
#  '/Volumes/GoogleDrive/My Drive/Optical_Simulations/FDTD_Simulation_Outputs/20200719/1.75eV/800nm',
#  '/Volumes/GoogleDrive/My Drive/Optical_Simulations/FDTD_Simulation_Outputs/20200719/1.65eV/350nm',
#  '/Volumes/GoogleDrive/My Drive/Optical_Simulations/FDTD_Simulation_Outputs/20200719/1.65eV/500nm',
# ...

# %%
fid_dict = {}
for n in tqdm(range(len(fidsearch))):
    R_fp = os.path.join(fidsearch[n],'reflection_export.txt')
    T_fp = os.path.join(fidsearch[n],'transmission_export.txt')
    PSK_fp = os.path.join(fidsearch[n],'PSK_EQE.txt')
    SI_fp = os.path.join(fidsearch[n],'Si_EQE.txt')
    Spectrum_fp = os.path.join('Spectrum_Import','AM15.csv')
    RayTracing_fp = os.path.join('RT_Outputs','RAT_data_7.csv')
    
    #each bandgap psk has its own cutoff...
    if n>=0 and n<=2:
        fid_dict[n]=FDTD_processing.FDTD_load(R_fp, T_fp, PSK_fp, SI_fp, Spectrum_fp, RayTracing_fp, Gap_cutoff=117, monitor_rez=200, plot=False)
    if n>=3 and n<=6:
        fid_dict[n]=FDTD_processing.FDTD_load(R_fp, T_fp, PSK_fp, SI_fp, Spectrum_fp, RayTracing_fp, Gap_cutoff=90, monitor_rez=200, plot=False)
    if n>=7 and n<=10:
        fid_dict[n]=FDTD_processing.FDTD_load(R_fp, T_fp, PSK_fp, SI_fp, Spectrum_fp, RayTracing_fp, Gap_cutoff=100, monitor_rez=200, plot=False)
    if n>=11 and n<=14:
        fid_dict[n]=FDTD_processing.FDTD_load(R_fp, T_fp, PSK_fp, SI_fp, Spectrum_fp, RayTracing_fp, Gap_cutoff=95, monitor_rez=200, plot=False)
# Out:
# 100%|██████████| 15/15 [00:00<00:00, 27.30it/s]

# %%
# adding sample descriptors manually for now... Can extract from file ID if structure is static in future...
data = {
    'Top_Eg':        [1.5, 1.5, 1.5, 1.75, 1.75, 1.75, 1.75, 1.65, 1.65, 1.65, 1.65, 1.69, 1.69, 1.69, 1.69,],
    'Top_Thickness': [650, 350, 500, 350, 500, 650, 800, 350, 500, 650, 800, 350, 500, 650, 800],
    'R_Jsc': [],
    'PA_Jsc': [],
    'PSK_Jsc': [],
    'Si_Jsc': [],
}
    
for n in range(len(fidsearch)):
    R_Jsc = fid_dict[n]['R_Jsc']
    PA_Jsc = fid_dict[n]['PA_Jsc']
    PSK_Jsc = fid_dict[n]['PSK_Jsc']
    Si_Jsc = fid_dict[n]['Si_Jsc']
    data['R_Jsc'].append(R_Jsc)
    data['PA_Jsc'].append(PA_Jsc)
    data['PSK_Jsc'].append(PSK_Jsc)
    data['Si_Jsc'].append(Si_Jsc)
    
df = pd.DataFrame(data)
# df

# %% [markdown]
# ### Creating a FoM

# %%
df['Match']= df['PSK_Jsc'] - df['Si_Jsc']
df['Total_unlimited']= df['PSK_Jsc'] + df['Si_Jsc']
df['Total_limited']=np.nan

for n in range(0, len(df)):
    a = df['PSK_Jsc'][n]
    b = df['Si_Jsc'][n]
    if a < b:
        c = a
    if a > b:
        c = b
    if a == b:
        c = a
    df['Total_limited'][n] = c

result1 = df.pivot(index = 'Top_Thickness', columns = 'Top_Eg' , values='Total_limited')
ax1=sns.heatmap(result1, annot=True, fmt ='.2f', cmap='Greens', vmin=15, vmax=20)
plt.ylabel('Perovskite Thickness $(nm)$')
plt.xlabel('Perovskite Bandgap $(eV)$')
ax1.invert_yaxis()
plt.title('Limited Tandem   $J_{sc}$ $ (mA)$')
plt.show()

result2 = df.pivot(index = 'Top_Thickness', columns = 'Top_Eg' , values='Match')
ax2 = sns.heatmap(result2, annot=True, fmt ='.2f', cmap='RdBu', vmin=-10, vmax=10)
plt.ylabel('Perovskite Thickness $(nm)$')
plt.xlabel('Perovskite Bandgap $(eV)$')
ax2.invert_yaxis()
plt.title('Tandem Current Mismatch Top-Bottom  $J_{sc}$ $ (mA)$')
plt.show()
